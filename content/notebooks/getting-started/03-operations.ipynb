# %% [markdown]
# # Operations continued
# We have been using a visual editor to create quantum circuits throughout the course. Now it's your turn to create some circuits on your own using qrisp, the next generation  quantum programming framework!
#
# This notebook will help you deepen your understanding of quantum operations and universal gate sets introduced in the lecture.
#
# You will:
# - Review single- and two-qubit gates.
# - Learn about universal gate sets and circuit transpilation.
# - Specify the physical qubits using **Qrisp**.
# - Transpile multi-controlled gates into a universal two-qubit gate set.
#
#
# In order to use qrisp together with IQM devices, please make sure to install the latest version of qrisp.

# %%
# %pip install "iqm-client[qiskit] >= 32.1.1, < 33.0"
# %pip install "qrisp[iqm]"
# Out:
# Looking in indexes: https://pypi.org, https://pypi.org/simple
# Collecting qrisp[iqm]
#   Downloading qrisp-0.7.11-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: numpy>=2.0 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from qrisp[iqm]) (2.3.4)
# Collecting sympy<=1.13 (from qrisp[iqm])
#   Using cached sympy-1.13.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: qiskit>=0.44.0 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from qrisp[iqm]) (1.4.2)
# Requirement already satisfied: matplotlib>=3.5.1 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from qrisp[iqm]) (3.10.7)
# Requirement already satisfied: scipy>=1.10.0 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from qrisp[iqm]) (1.15.3)
# Collecting numba (from qrisp[iqm])
#   Using cached numba-0.62.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.8 kB)
# Requirement already satisfied: networkx in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from qrisp[iqm]) (3.5)
# Collecting tdqm (from qrisp[iqm])
#   Using cached tdqm-0.0.1-py3-none-any.whl
# Requirement already satisfied: dill in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from qrisp[iqm]) (0.4.0)
# Collecting flask (from qrisp[iqm])
#   Using cached flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting waitress (from qrisp[iqm])
#   Using cached waitress-3.0.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pyyaml in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from qrisp[iqm]) (6.0)
# Requirement already satisfied: requests in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from qrisp[iqm]) (2.32.3)
# Requirement already satisfied: psutil in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from qrisp[iqm]) (7.1.1)
# Collecting jax==0.6.0 (from qrisp[iqm])
#   Using cached jax-0.6.0-py3-none-any.whl.metadata (22 kB)
# Collecting jaxlib==0.6.0 (from qrisp[iqm])
#   Using cached jaxlib-0.6.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (1.2 kB)
# Requirement already satisfied: iqm-client[qiskit] in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from qrisp[iqm]) (30.2.0)
# Collecting ml_dtypes>=0.5.0 (from jax==0.6.0->qrisp[iqm])
#   Using cached ml_dtypes-0.5.3-cp311-cp311-macosx_10_9_universal2.whl.metadata (8.9 kB)
# Collecting opt_einsum (from jax==0.6.0->qrisp[iqm])
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from sympy<=1.13->qrisp[iqm]) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from matplotlib>=3.5.1->qrisp[iqm]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from matplotlib>=3.5.1->qrisp[iqm]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from matplotlib>=3.5.1->qrisp[iqm]) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from matplotlib>=3.5.1->qrisp[iqm]) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from matplotlib>=3.5.1->qrisp[iqm]) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from matplotlib>=3.5.1->qrisp[iqm]) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from matplotlib>=3.5.1->qrisp[iqm]) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from matplotlib>=3.5.1->qrisp[iqm]) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.5.1->qrisp[iqm]) (1.16.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from qiskit>=0.44.0->qrisp[iqm]) (0.17.1)
# Requirement already satisfied: stevedore>=3.0.0 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from qiskit>=0.44.0->qrisp[iqm]) (5.5.0)
# Requirement already satisfied: typing-extensions in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from qiskit>=0.44.0->qrisp[iqm]) (4.15.0)
# Requirement already satisfied: symengine<0.14,>=0.11 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from qiskit>=0.44.0->qrisp[iqm]) (0.13.0)
# Collecting blinker>=1.9.0 (from flask->qrisp[iqm])
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting click>=8.1.3 (from flask->qrisp[iqm])
#   Using cached click-8.3.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting itsdangerous>=2.2.0 (from flask->qrisp[iqm])
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting jinja2>=3.1.2 (from flask->qrisp[iqm])
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from flask->qrisp[iqm]) (3.0.3)
# Collecting werkzeug>=3.1.0 (from flask->qrisp[iqm])
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting iqm-station-control-client<10,>=9 (from iqm-client[qiskit]; extra == "iqm"->qrisp[iqm])
#   Using cached iqm_station_control_client-9.18.0-py3-none-any.whl.metadata (14 kB)
# Collecting iqm-exa-common<27,>=26 (from iqm-client[qiskit]; extra == "iqm"->qrisp[iqm])
#   Using cached iqm_exa_common-26.33.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: pydantic<3.0,>=2.9.2 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (2.12.3)
# Requirement already satisfied: qiskit-aer<0.18,>=0.13.1 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (0.17.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from requests->qrisp[iqm]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from requests->qrisp[iqm]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from requests->qrisp[iqm]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from requests->qrisp[iqm]) (2025.10.5)
# Requirement already satisfied: iqm-data-definitions<3.0,>=2.13 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from iqm-exa-common<27,>=26->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (2.19)
# Requirement already satisfied: python-dotenv==0.21.1 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from iqm-exa-common<27,>=26->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (0.21.1)
# Requirement already satisfied: xarray==2024.10.0 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from iqm-exa-common<27,>=26->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (2024.10.0)
# Requirement already satisfied: types-requests in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from iqm-exa-common<27,>=26->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (2.32.4.20250913)
# Requirement already satisfied: ruamel-yaml==0.17.32 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from iqm-exa-common<27,>=26->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (0.17.32)
# Requirement already satisfied: ruamel-yaml-clib==0.2.8 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from iqm-exa-common<27,>=26->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (0.2.8)
# INFO: pip is looking at multiple versions of iqm-exa-common to determine which version is compatible with other requirements. This could take a while.
#   Using cached iqm_exa_common-26.32.0-py3-none-any.whl.metadata (14 kB)
#   Using cached iqm_exa_common-26.31.0-py3-none-any.whl.metadata (14 kB)
#   Using cached iqm_exa_common-26.30.0-py3-none-any.whl.metadata (14 kB)
#   Using cached iqm_exa_common-26.29.0-py3-none-any.whl.metadata (14 kB)
#   Using cached iqm_exa_common-26.28.0-py3-none-any.whl.metadata (14 kB)
#   Using cached iqm_exa_common-26.27.0-py3-none-any.whl.metadata (14 kB)
#   Using cached iqm_exa_common-26.26.0-py3-none-any.whl.metadata (14 kB)
# INFO: pip is still looking at multiple versions of iqm-exa-common to determine which version is compatible with other requirements. This could take a while.
#   Using cached iqm_exa_common-26.25.1-py3-none-any.whl.metadata (14 kB)
#   Using cached iqm_exa_common-26.25.0-py3-none-any.whl.metadata (14 kB)
#   Using cached iqm_exa_common-26.24.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: pandas>=2.1 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from xarray==2024.10.0->iqm-exa-common<27,>=26->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (2.3.3)
# Requirement already satisfied: protobuf<5.0,>=4.25.3 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from iqm-data-definitions<3.0,>=2.13->iqm-exa-common<27,>=26->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (4.25.8)
# Requirement already satisfied: types-protobuf in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from iqm-data-definitions<3.0,>=2.13->iqm-exa-common<27,>=26->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (6.32.1.20250918)
# Requirement already satisfied: scipy-stubs in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from iqm-data-definitions<3.0,>=2.13->iqm-exa-common<27,>=26->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.16.2.4)
# Requirement already satisfied: opentelemetry-exporter-otlp<2.0,>=1.25.0 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from iqm-station-control-client<10,>=9->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.25.0)
# Requirement already satisfied: grpcio<2.0,>=1.65.4 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from iqm-station-control-client<10,>=9->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.75.1)
# Requirement already satisfied: tqdm>=4.59.0 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from iqm-station-control-client<10,>=9->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (4.67.1)
# Requirement already satisfied: types-tqdm in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from iqm-station-control-client<10,>=9->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (4.67.0.20250809)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.25.0 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<10,>=9->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.25.0 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<10,>=9->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.25.0)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<10,>=9->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.2.18)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<10,>=9->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.71.0)
# Requirement already satisfied: opentelemetry-api~=1.15 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<10,>=9->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.25.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.25.0 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<10,>=9->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.25.0)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<10,>=9->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.25.0)
# Requirement already satisfied: opentelemetry-sdk~=1.25.0 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<10,>=9->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.25.0)
# Requirement already satisfied: importlib-metadata<=7.1,>=6.0 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from opentelemetry-api~=1.15->opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<10,>=9->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (7.1.0)
# Requirement already satisfied: zipp>=0.5 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from importlib-metadata<=7.1,>=6.0->opentelemetry-api~=1.15->opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<10,>=9->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from opentelemetry-sdk~=1.25.0->opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<10,>=9->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (0.46b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from pydantic<3.0,>=2.9.2->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from pydantic<3.0,>=2.9.2->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from pydantic<3.0,>=2.9.2->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (0.4.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from deprecated>=1.2.6->opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp<2.0,>=1.25.0->iqm-station-control-client<10,>=9->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (1.17.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from pandas>=2.1->xarray==2024.10.0->iqm-exa-common<27,>=26->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from pandas>=2.1->xarray==2024.10.0->iqm-exa-common<27,>=26->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (2025.2)
# Collecting llvmlite<0.46,>=0.45.0dev0 (from numba->qrisp[iqm])
#   Using cached llvmlite-0.45.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Requirement already satisfied: optype<0.15,>=0.14.0 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from optype[numpy]<0.15,>=0.14.0->scipy-stubs->iqm-data-definitions<3.0,>=2.13->iqm-exa-common<27,>=26->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (0.14.0)
# Requirement already satisfied: numpy-typing-compat<20250819,>=20250818.1.25 in /Users/see/dev/iqm-academy-second-try/.venv/lib/python3.11/site-packages (from optype[numpy]<0.15,>=0.14.0->scipy-stubs->iqm-data-definitions<3.0,>=2.13->iqm-exa-common<27,>=26->iqm-client[qiskit]; extra == "iqm"->qrisp[iqm]) (20250818.2.3)
# Downloading qrisp-0.7.11-py3-none-any.whl (782 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 783.0/783.0 kB 1.3 MB/s  0:00:00 eta 0:00:01
# Using cached jax-0.6.0-py3-none-any.whl (2.3 MB)
# Using cached jaxlib-0.6.0-cp311-cp311-macosx_11_0_arm64.whl (53.5 MB)
# Using cached sympy-1.13.0-py3-none-any.whl (6.2 MB)
# Using cached ml_dtypes-0.5.3-cp311-cp311-macosx_10_9_universal2.whl (667 kB)
# Using cached flask-3.1.2-py3-none-any.whl (103 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached click-8.3.0-py3-none-any.whl (107 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Using cached iqm_exa_common-26.24.0-py3-none-any.whl (90 kB)
# Using cached iqm_station_control_client-9.18.0-py3-none-any.whl (98 kB)
# Using cached numba-0.62.1-cp311-cp311-macosx_11_0_arm64.whl (2.7 MB)
# Using cached llvmlite-0.45.1-cp311-cp311-macosx_11_0_arm64.whl (37.3 MB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Using cached waitress-3.0.2-py3-none-any.whl (56 kB)
# Installing collected packages: werkzeug, waitress, tdqm, sympy, opt_einsum, ml_dtypes, llvmlite, jinja2, itsdangerous, click, blinker, numba, jaxlib, flask, jax, qrisp, iqm-exa-common, iqm-station-control-client
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.14.0
#     Uninstalling sympy-1.14.0:90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/18 [sympy]
#       Successfully uninstalled sympy-1.14.0━━━━━━━━━━━━━━━━━━━━━━━  3/18 [sympy]
#   Attempting uninstall: jinja2╺━━━━━━━━━━━━━━━━━━━━━━━━━━  6/18 [llvmlite]m]
#     Found existing installation: Jinja2 3.0.3━━━━━━━━━━━━━━━━━  6/18 [llvmlite]
#     Uninstalling Jinja2-3.0.3:m━━━━━━━━━━━━━━━━━━━━━━━━━━  6/18 [llvmlite]
#       Successfully uninstalled Jinja2-3.0.3━━━━━━━━━━━━━━━━━━━  6/18 [llvmlite]
#   Attempting uninstall: iqm-exa-common━━━╺━━━━━━ 15/18 [qrisp]]
#     Found existing installation: iqm-exa-common 27.3.10m━━━━━━ 15/18 [qrisp]
#     Uninstalling iqm-exa-common-27.3.1:0m╺━━━━━━ 15/18 [qrisp]
#       Successfully uninstalled iqm-exa-common-27.3.1━━━━━━ 15/18 [qrisp]
#   Attempting uninstall: iqm-station-control-clientm━━━━━━ 15/18 [qrisp]
#     Found existing installation: iqm-station-control-client 11.3.1 15/18 [qrisp]
#     Uninstalling iqm-station-control-client-11.3.1:━━━━━━ 15/18 [qrisp]
#       Successfully uninstalled iqm-station-control-client-11.3.10m 15/18 [qrisp]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18/18 [iqm-station-control-client]on-control-client]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# iqm-pulla 11.16.2 requires iqm-exa-common<28,>=27, but you have iqm-exa-common 26.24.0 which is incompatible.
# iqm-pulla 11.16.2 requires iqm-station-control-client<12,>=11, but you have iqm-station-control-client 9.18.0 which is incompatible.
# iqm-pulse 12.6.1 requires iqm-exa-common<28,>=27, but you have iqm-exa-common 26.24.0 which is incompatible.
# iqm-pulse 12.6.1 requires jinja2==3.0.3, but you have jinja2 3.1.6 which is incompatible.
# Successfully installed blinker-1.9.0 click-8.3.0 flask-3.1.2 iqm-exa-common-26.24.0 iqm-station-control-client-9.18.0 itsdangerous-2.2.0 jax-0.6.0 jaxlib-0.6.0 jinja2-3.1.6 llvmlite-0.45.1 ml_dtypes-0.5.3 numba-0.62.1 opt_einsum-3.4.0 qrisp-0.7.11 sympy-1.13.0 tdqm-0.0.1 waitress-3.0.2 werkzeug-3.1.3
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Universal Gate Sets
#
# A **universal gate set** allows any quantum computation to be approximated to arbitrary accuracy.
#
# Common examples:
# - {H, T, CNOT}
# - {Rz, Rx, CZ}
# - {CZ, R}  (used in this notebook)
#
# The process of **transpilation** converts a general quantum circuit into one that uses only gates from the chosen universal set.
#
# **Task: Use the `qc.transpile(basis_gates=["cz", "r"])` method to transpile the circuit and compare it to the untranspiled version.**

# %%
# Import the Qrisp quantum library
from qrisp import *

# Define two qubits as a quantum variable
q = QuantumVariable(2)

# Apply a Hadamard to the first qubit
h(q[0])

# Apply a CNOT (control: q[0], target: q[1])
cx(q[0], q[1])

# Visualize and compile
qc = q.qs.compile()
print(qc)

print("TODO: print the transpiled circuit diagram here")

# %% [markdown]
# ## Multi-Controlled Gates and Decomposition
#
# The **multi-controlled X gate (MCX)** generalizes the CNOT gate.
# For example, `mcx([0,1,2], 3)` flips qubit 3 if all control qubits (0,1,2) are in state `1`.
#
# However, **quantum hardware** typically only supports *two-qubit gates*, so multi-controlled gates must be **decomposed** into equivalent two-qubit operations.
#
# **Task: Create a circuit that uses the MCX gate and transpile it to see how it is decomposed into two-qubit gates.**

# %%
# Define 4 qubits
qv = QuantumVariable(4)

# Apply a multi-controlled X (at least three controls -> one target)

# Compile and transpile

# Transpile to two-qubit universal gate set

# %% [markdown]
# **Task: MCX Decomposition**
#
# 1. Observe the above transpiled version of the `mcx` gate (tip: use `__dir__()` on the object return by the `transpile` method).
# 2. How many **two-qubit** gates does it require?
# 3. Compare the number of required cz gates to the number of required iswap gates when considering the universal gate set that includes iSWAP as the two-qubit gate {iSWAP, R}.
# 4. For the quick ones: Try building your own 3-control gate manually using `cx` and `cz` gates only.

# %% [markdown]
# When running on hardware, this transpilation is automatically handled for us, however, it makes sense to understand what is happening "under the hood".

# %% [markdown]
# ## Improving outcomes by selecting physical qubits
#
# A typical quantum processor consists of multiple qubits with varying coherence times and gate fidelities. By selecting the best physical qubits for your circuit, you can improve the overall performance and reliability of your quantum computations.
#
# This can be done in any framework. For qrisp, the following is a way to do it:
#
# **Task: But, oops, the coupling map is incomplete, check IQM Resonance's coupling map and add at least one edge to give the transpiler enough freedom to map the circuit.**

# %%
from qrisp.interface import IQMBackend

import qiskit
# Define a custom transpilation procedure (default will be default 
# qiskit transpiler to match connectivity and gate set).
# Should take a Qiskit circuit and return a Qiskit circuit


qb_index = lambda q: int(q.strip().upper().replace("QB", "")) - 1 if q.strip().upper().startswith("QB") else None


def custom_transpilation(qc : qiskit.QuantumCircuit):
    # TODO: Check and change only the next line
    couplings = [["QB15","QB16"],["QB16","QB24"],["QB23","QB24"],["QB23","QB15"]] 
    reduced_coupling_map = [[qb_index(q) for q in row] for row in couplings]
    qc = qiskit.transpile(qc, basis_gates = ["cz", "r", "measure", "reset"], coupling_map=reduced_coupling_map, optimization_level=3)
        
    return qc
    
# Create a backend object
quantum_computer = IQMBackend(api_token = input("Enter your IQM Resonance API token: "), 
                          device_instance = "emerald",
                          transpiler = custom_transpilation)


qv = QuantumVariable(5)

x(qv[0])
cx(qv[0], qv[1])
cx(qv[1], qv[2])
cx(qv[2], qv[3])
cx(qv[3], qv[4])


meas_res = qv.get_measurement(backend = quantum_computer)

# %% [markdown]
# **Task: Then, try to find qubits with low readout errors and good two-qubit gate fidelities for your circuit.**
